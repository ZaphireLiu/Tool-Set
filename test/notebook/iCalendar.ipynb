# %%
import sqlite3

conn = sqlite3.connect('test.db')

print ("数据库打开成功")
# Out:
# 数据库打开成功

# %%
import icalendar
from pathlib import Path

# %%
ics_path = Path("test.ics")
calendar = icalendar.Calendar.from_ical(ics_path.read_bytes())
for event in calendar.events:
    print(event)
    break
# Out:
# VEVENT({'SUMMARY': vText(b'\xe7\xbb\x9d\xe5\x8c\xba\xe9\x9b\xb6 2.1 \xe7\x89\x88\xe6\x9c\xac'), 'DTSTART': vDDDTypes(2025-07-16 07:00:00+08:00, Parameters({'TZID': 'Asia/Shanghai'})), 'UID': vText(b'4d07141e@trrw.tech'), 'DESCRIPTION': vText(b'\xe7\xbb\x9d\xe5\x8c\xba\xe9\x9b\xb6 2.1 \xe7\x89\x88\xe6\x9c\xac'), 'LOCATION': vText(b'\xe7\xbb\x9d\xe5\x8c\xba\xe9\x9b\xb6-\xe7\x89\x88\xe6\x9c\xac\xe4\xbf\xa1\xe6\x81\xaf'), 'TRANSP': vText(b'TRANSPARENT')})
